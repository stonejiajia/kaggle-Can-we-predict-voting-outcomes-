# %%
import pandas as pd

# %%
train = pd.read_csv("train2016.csv")

# %%
train.head(5)
# Out:
#    USER_ID     YOB  Gender               Income             HouseholdStatus  \
# 0        1  1938.0    Male                  NaN            Married (w/kids)
# 1        4  1970.0  Female        over $150,000  Domestic Partners (w/kids)
# 2        5  1997.0    Male   $75,000 - $100,000            Single (no kids)
# 3        8  1983.0    Male  $100,001 - $150,000            Married (w/kids)
# 4        9  1984.0  Female    $50,000 - $74,999            Married (w/kids)
#
#         EducationLevel       Party Q124742 Q124122 Q123464  ...   Q100010  \
# 0                  NaN    Democrat      No     NaN      No  ...       Yes
# 1    Bachelor's Degree    Democrat     NaN     Yes      No  ...       NaN
# 2  High School Diploma  Republican     NaN     Yes     Yes  ...       Yes
# 3    Bachelor's Degree    Democrat      No     Yes      No  ...        No
# 4  High School Diploma  Republican      No     Yes      No  ...       Yes
#
# ...

# %%
train
# Out:
#       USER_ID     YOB  Gender               Income  \
# 0           1  1938.0    Male                  NaN
# 1           4  1970.0  Female        over $150,000
# 2           5  1997.0    Male   $75,000 - $100,000
# 3           8  1983.0    Male  $100,001 - $150,000
# 4           9  1984.0  Female    $50,000 - $74,999
# 5          10  1997.0  Female        over $150,000
# 6          11  1983.0    Male    $25,001 - $50,000
# 7          12  1996.0    Male   $75,000 - $100,000
# 8          13     NaN    Male                  NaN
# 9          15  1981.0  Female    $50,000 - $74,999
# 10         16  1971.0    Male        over $150,000
# 11         17  1977.0  Female  $100,001 - $150,000
# 12         18  1971.0    Male    $50,000 - $74,999
# 13         19  1996.0    Male   $75,000 - $100,000
# 14         20  1970.0    Male   $75,000 - $100,000
# 15         21  1979.0    Male        over $150,000
# 16         22  1997.0  Female   $75,000 - $100,000
# ...

# %%
test = pd.read_csv("test2016.csv")

# %%
test
# Out:
#       USER_ID     YOB  Gender               Income  \
# 0           2  1985.0  Female    $25,001 - $50,000
# 1           3  1983.0    Male    $50,000 - $74,999
# 2           6  1995.0    Male   $75,000 - $100,000
# 3           7  1980.0  Female    $50,000 - $74,999
# 4          14  1980.0  Female                  NaN
# 5          28  1973.0    Male        over $150,000
# 6          29  1968.0  Female    $50,000 - $74,999
# 7          37  1961.0    Male        over $150,000
# 8          44  1989.0  Female        under $25,000
# 9          56  1975.0    Male   $75,000 - $100,000
# 10         62  1958.0  Female    $50,000 - $74,999
# 11         68  1960.0  Female   $75,000 - $100,000
# 12         72  1985.0    Male    $50,000 - $74,999
# 13         74  1978.0    Male    $50,000 - $74,999
# 14         80  1998.0  Female   $75,000 - $100,000
# 15         81  1966.0    Male        over $150,000
# 16         87  1990.0    Male    $25,001 - $50,000
# ...

# %%
 import openpyxl
